# %% [markdown]
# # Linear Regression Prediction Model
# First, we will split the data with training vs testing data

# %%
import pandas as pd 
df = pd.read_csv("socal2.csv")
df.head(7)
# Out:
#    image_id                 street             citi  n_citi  bed  bath  sqft  \
# 0         0  1317 Van Buren Avenue  Salton City, CA     317    3   2.0  1560
# 1         1         124 C Street W      Brawley, CA      48    3   2.0   713
# 2         2        2304 Clark Road     Imperial, CA     152    3   1.0   800
# 3         3     755 Brawley Avenue      Brawley, CA      48    3   1.0  1082
# 4         4  2207 R Carrillo Court     Calexico, CA      55    4   3.0  2547
# 5         5     755 Brawley Avenue      Brawley, CA      48    3   1.0  1082
# 6         6    1100 CAMILIA Street     Calexico, CA      55    4   3.0  2769
#
#     price
# 0  201900
# 1  228500
# 2  273950
# 3  350000
# 4  385100
# 5  350000
# 6  415000

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
plt.scatter(df['sqft'], df['price'])

# %%
plt.scatter(df['n_citi'], df['price'])

# %%
plt.scatter(df['bath'], df['price'])

# %%
plt.scatter(df['bed'], df['price'])

# %% [markdown]
# Set your dependent variables to x and your dependent variables to y

# %%
x = df[['bed', 'bath', 'n_citi', 'sqft']]
y = df['price']

# %%
x
y
# Out:
# 0        201900
# 1        228500
# 2        273950
# 3        350000
# 4        385100
#           ...
# 15469    949000
# 15470    949900
# 15471    920000
# 15472    997000
# 15473    975000
# Name: price, Length: 15474, dtype: int64

# %% [markdown]
# We will now split the data and specify the percent train and percent test data sets
#
# We are making our training set 80% and our testing set 20% of the data

# %%
from sklearn.model_selection import train_test_split

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2)

# %%
len(x_test)
# Out:
# 3095

# %%
from sklearn.linear_model import LinearRegression
clf = LinearRegression()

clf.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
clf.predict(x_test)
# Out:
# array([1055057.23798052,  505817.05228415,  754676.90041893, ...,
#         594931.62401583,  827207.85819075, 1177984.36160115])

# %%
y_test
# Out:
# 4928     1200000
# 1792      499000
# 3225     1325000
# 6382      479990
# 11181     270000
#           ...
# 8414      229800
# 5379      247500
# 12880     799000
# 7843      795000
# 5007     1329000
# Name: price, Length: 3095, dtype: int64

# %%
clf.score(x_test, y_test)
# Out:
# 0.35372311303344484

# %% [markdown]
# This thus proves that this model is not very accurate to predicting the house prices to the data set, seeing how the accuracy is at 14%!
